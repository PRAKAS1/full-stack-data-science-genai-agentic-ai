# %%
for i in range(1,5):
    i=i+1
    print('# # # #')
# Out:
# # # # #
# # # # #
# # # # #
# # # # #

# %%
num=12
for i in range(1,num):
    if i%2==0:
        print('Not Prime', i)
    else:
         print('Prime', i)
        
else:
    print('Prime',i)
# Out:
# Prime 1
# Not Prime 2
# Prime 3
# Not Prime 4
# Prime 5
# Not Prime 6
# Prime 7
# Not Prime 8
# Prime 9
# Not Prime 10
# Prime 11
# Prime 11

# %%
for i in range(1,10):
# Out:
#   Cell In[17], line 1
#     for i in range(1,10):
#                          ^
# _IncompleteInputError: incomplete input

# %%
for i in range(1,10):
    pass
