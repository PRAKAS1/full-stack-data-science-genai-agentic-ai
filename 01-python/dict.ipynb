# %%
d={1:'one',2:'two'}

# %%
type(d)
# Out:
# dict

# %%
d.keys()
# Out:
# dict_keys([1, 2])

# %%
d.values()
# Out:
# dict_values(['one', 'two'])

# %%
d[3]='three'

# %%
d[4]='four'

# %%
d
# Out:
# {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %%
d.pop('four')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 d.pop('four')
#
# KeyError: 'four'
