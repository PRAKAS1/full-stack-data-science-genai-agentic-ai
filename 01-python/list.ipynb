# %%
list1 = [] # Empty List

# %%
list1=[11,22,14,11,6,32,123]

# %%
list2=[4,87,12,4]

# %%
list1.sort()

# %%
list1
# Out:
# [6, 11, 11, 14, 22, 32, 123]

# %%
list1.sort(reverse=True)

# %%
list1
# Out:
# [123, 32, 22, 14, 11, 11, 6]

# %%
list1.append(list2)

# %%
list1
# Out:
# [123, 32, 22, 14, 11, 11, 6, [4, 87, 12, 4]]

# %%
list2
# Out:
# [4, 87, 12, 4]

# %%
list1
# Out:
# [123, 32, 22, 14, 11, 11, 6, [4, 87, 12, 4]]

# %%
len(list1)
# Out:
# 8

# %%
list[-1]
# Out:
# list[-1]

# %%
list[-1]
# Out:
# list[-1]
