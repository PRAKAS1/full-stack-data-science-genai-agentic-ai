# %%
# image convert to array

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in C:\Users\praka\anaconda3\Lib\site-packages (12.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image # python imageing library

# %%
image= Image.open(r'C:\Users\praka\source\full-stack-data-science-genai-agentic-ai\pic.jpg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x399>

# %%
type(image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
image_arr=np.asarray(image)
image_arr
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[ 54,  41,  59],
#         [ 74,  59,  78],
#         [ 60,  39,  58],
#         ...,
#         [ 93,  44,  65],
#         [ 95,  44,  63],
#         [ 96,  43,  63]],
#
#        [[ 44,  32,  56],
#         [ 68,  54,  77],
#         [ 52,  32,  57],
#         ...,
#         [ 95,  46,  68],
#         [ 97,  45,  67],
#         [ 98,  44,  67]],
#
#        [[ 45,  35,  62],
#         [ 54,  41,  67],
#         [ 53,  37,  64],
#         ...,
#         [ 99,  50,  72],
#         [101,  49,  71],
#         [101,  49,  71]]], shape=(399, 299, 3), dtype=uint8)

# %%
image_arr.shape
# Out:
# (399, 299, 3)

# %%
plt.imshow(image_arr)
plt.show()
