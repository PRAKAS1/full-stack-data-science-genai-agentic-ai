# %%
i = 1

while i <5:
    print('data science')
    i=i+1
# Out:
# data science
# data science
# data science
# data science

# %%
i = 1

while i <5:
    print('data science',end='-')
    j=1
    while j <4:
        print('tech',end='-')
        j=j+1
    i=i+1
    print()
# Out:
# data science-tech-tech-tech-
# data science-tech-tech-tech-
# data science-tech-tech-tech-
# data science-tech-tech-tech-
